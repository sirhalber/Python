# %%
#Intro
import numpy as np
import pandas as pd
import codecademylib3

students = pd.read_csv('students.csv')

#print the first five rows of students:
print(students.head())

#separate out scores for students who live in urban and rural locations:
scores_urban = students.G3[students.address == 'U']
scores_rural = students.G3[students.address == 'R']

print(scores_urban)
print(scores_rural)

# %%
#Mean and median diff
import numpy as np
import pandas as pd
students = pd.read_csv('students.csv')

scores_urban = students.G3[students.address == 'U']
scores_rural = students.G3[students.address == 'R']

#calculate means for each group:
scores_urban_mean = scores_urban.mean()
scores_rural_mean = scores_rural.mean()

#print mean scores:
print('Mean score - students w/ urban address:')
print(scores_urban_mean)
print('Mean score - students w/ rural address:')
print(scores_rural_mean)

#calculate mean difference:
mean_diff = scores_urban_mean - scores_rural_mean

#print mean difference
print('Mean difference:')
print(mean_diff)

#calculate medians for each group:
scores_urban_median = scores_urban.median()
scores_rural_median = scores_rural.median()

#print median scores
print('Median score - students w/ urban address:')
print(scores_urban_median)
print('Median score - students w/ rural address:')
print(scores_rural_median)

#calculate median difference
median_diff = scores_urban_median - scores_rural_median

#print median difference
print('Median difference:')
print(median_diff)

# %%
#Side-by-side plots
import pandas as pd
import codecademylib3
import matplotlib.pyplot as plt 
import seaborn as sns

students = pd.read_csv('students.csv')

#create the boxplot here:
sns.boxplot(data = students, x = 'address', y = 'G3')
plt.show()

# %%
#Overlapping Histograms
import numpy as np
import pandas as pd
import codecademylib3
import matplotlib.pyplot as plt 
students = pd.read_csv('students.csv')

scores_urban = students.G3[students.address == 'U']
scores_rural = students.G3[students.address == 'R']

#create the overlapping histograms here:
plt.hist(scores_urban , color="blue", label="Urban", \
normed=True, alpha=0.5)
plt.hist(scores_rural , color="red", label="Rural", \
normed=True, alpha=0.5)
plt.legend()

# %%
#Non-binary Categorical Variables
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import codecademylib3

students = pd.read_csv('students.csv')

#create the box-plot here:
sns.boxplot(data = students, x = 'Fjob', y = 'G3')
plt.show()

# %%
#Review
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import codecademylib3

titanic = pd.read_csv('titanic.csv')

titanic_surv = titanic.Fare[titanic.Survived == 1]
titanic_died = titanic.Fare[titanic.Survived == 0]

print(titanic_surv)
print(titanic_died)

#Difference in mean
titanic_surv_mean = titanic_surv.mean()
titanic_died_mean = titanic_died.mean()
titanic_mean_diff = titanic_surv_mean - titanic_died_mean
print(titanic_mean_diff)

#Difference in median
titanic_surv_median = titanic_surv.median()
titanic_died_median = titanic_died.median()
titanic_median_diff = titanic_surv_median - titanic_died_median
print(titanic_median_diff)

#Side-by-side box plots
sns.boxplot(data = titanic, x = 'Survived', y = 'Fare')
plt.show()

#Overlapping histograms
plt.hist(titanic_surv, color="blue", label="Survived", \
normed=True, alpha=0.5)
plt.hist(titanic_died , color="red", label="Died", \
normed=True, alpha=0.5)
plt.legend()
plt.show()
